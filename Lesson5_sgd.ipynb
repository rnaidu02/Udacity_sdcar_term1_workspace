# %% [markdown]
# #### Base code (functions)

# %%
import numpy as np


class Node(object):
    """
    Base class for nodes in the network.

    Arguments:

        `inbound_nodes`: A list of nodes with edges into this node.
    """
    def __init__(self, inbound_nodes=[]):
        """
        Node's constructor (runs when the object is instantiated). Sets
        properties that all nodes need.
        """
        # A list of nodes with edges into this node.
        self.inbound_nodes = inbound_nodes
        # The eventual value of this node. Set by running
        # the forward() method.
        self.value = None
        # A list of nodes that this node outputs to.
        self.outbound_nodes = []
        # New property! Keys are the inputs to this node and
        # their values are the partials of this node with
        # respect to that input.
        self.gradients = {}
        # Sets this node as an outbound node for all of
        # this node's inputs.
        for node in inbound_nodes:
            node.outbound_nodes.append(self)

    def forward(self):
        """
        Every node that uses this class as a base class will
        need to define its own `forward` method.
        """
        raise NotImplementedError

    def backward(self):
        """
        Every node that uses this class as a base class will
        need to define its own `backward` method.
        """
        raise NotImplementedError


class Input(Node):
    """
    A generic input into the network.
    """
    def __init__(self):
        # The base class constructor has to run to set all
        # the properties here.
        #
        # The most important property on an Input is value.
        # self.value is set during `topological_sort` later.
        Node.__init__(self)

    def forward(self):
        # Do nothing because nothing is calculated.
        pass

    def backward(self):
        # An Input node has no inputs so the gradient (derivative)
        # is zero.
        # The key, `self`, is reference to this object.
        self.gradients = {self: 0}
        # Weights and bias may be inputs, so you need to sum
        # the gradient from output gradients.
        for n in self.outbound_nodes:
            self.gradients[self] += n.gradients[self]

class Linear(Node):
    """
    Represents a node that performs a linear transform.
    """
    def __init__(self, X, W, b):
        # The base class (Node) constructor. Weights and bias
        # are treated like inbound nodes.
        Node.__init__(self, [X, W, b])

    def forward(self):
        """
        Performs the math behind a linear transform.
        """
        X = self.inbound_nodes[0].value
        W = self.inbound_nodes[1].value
        b = self.inbound_nodes[2].value
        self.value = np.dot(X, W) + b

    def backward(self):
        """
        Calculates the gradient based on the output values.
        """
        # Initialize a partial for each of the inbound_nodes.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        # Cycle through the outputs. The gradient will change depending
        # on each output, so the gradients are summed over all outputs.
        for n in self.outbound_nodes:
            # Get the partial of the cost with respect to this node.
            grad_cost = n.gradients[self]
            # Set the partial of the loss with respect to this node's inputs.
            self.gradients[self.inbound_nodes[0]] += np.dot(grad_cost, self.inbound_nodes[1].value.T)
            # Set the partial of the loss with respect to this node's weights.
            self.gradients[self.inbound_nodes[1]] += np.dot(self.inbound_nodes[0].value.T, grad_cost)
            # Set the partial of the loss with respect to this node's bias.
            self.gradients[self.inbound_nodes[2]] += np.sum(grad_cost, axis=0, keepdims=False)


class Sigmoid(Node):
    """
    Represents a node that performs the sigmoid activation function.
    """
    def __init__(self, node):
        # The base class constructor.
        Node.__init__(self, [node])

    def _sigmoid(self, x):
        """
        This method is separate from `forward` because it
        will be used with `backward` as well.

        `x`: A numpy array-like object.
        """
        return 1. / (1. + np.exp(-x))

    def forward(self):
        """
        Perform the sigmoid function and set the value.
        """
        input_value = self.inbound_nodes[0].value
        self.value = self._sigmoid(input_value)

    def backward(self):
        """
        Calculates the gradient using the derivative of
        the sigmoid function.
        """
        # Initialize the gradients to 0.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        # Sum the partial with respect to the input over all the outputs.
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            sigmoid = self.value
            self.gradients[self.inbound_nodes[0]] += sigmoid * (1 - sigmoid) * grad_cost


class MSE(Node):
    def __init__(self, y, a):
        """
        The mean squared error cost function.
        Should be used as the last node for a network.
        """
        # Call the base class' constructor.
        Node.__init__(self, [y, a])

    def forward(self):
        """
        Calculates the mean squared error.
        """
        # NOTE: We reshape these to avoid possible matrix/vector broadcast
        # errors.
        #
        # For example, if we subtract an array of shape (3,) from an array of shape
        # (3,1) we get an array of shape(3,3) as the result when we want
        # an array of shape (3,1) instead.
        #
        # Making both arrays (3,1) insures the result is (3,1) and does
        # an elementwise subtraction as expected.
        y = self.inbound_nodes[0].value.reshape(-1, 1)
        a = self.inbound_nodes[1].value.reshape(-1, 1)

        self.m = self.inbound_nodes[0].value.shape[0]
        # Save the computed output for backward.
        self.diff = y - a
        self.value = np.mean(self.diff**2)

    def backward(self):
        """
        Calculates the gradient of the cost.
        """
        self.gradients[self.inbound_nodes[0]] = (2 / self.m) * self.diff
        self.gradients[self.inbound_nodes[1]] = (-2 / self.m) * self.diff


def topological_sort(feed_dict):
    """
    Sort the nodes in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` Node and the value is the respective value feed to that Node.

    Returns a list of sorted nodes.
    """

    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L


def forward_and_backward(graph):
    """
    Performs a forward pass and a backward pass through a list of sorted Nodes.

    Arguments:

        `graph`: The result of calling `topological_sort`.
    """
    # Forward pass
    for n in graph:
        n.forward()

    # Backward pass
    # see: https://docs.python.org/2.3/whatsnew/section-slices.html
    for n in graph[::-1]:
        n.backward()


def sgd_update(trainables, learning_rate=1e-2):
    """
    Updates the value of each trainable with SGD.

    Arguments:

        `trainables`: A list of `Input` Nodes representing weights/biases.
        `learning_rate`: The learning rate.
    """
    # TODO: update all the `trainables` with SGD
    # You can access and assign the value of a trainable with `value` attribute.
    # Example:
    # for t in trainables:
    #   t.value = your implementation here
    
    for t in trainables:
        t.value -= learning_rate * t.gradients[t] 
    pass

# %% [markdown]
# #### Main function

# %% [markdown]
# [url](https://d17h27t6h515a5.cloudfront.net/topher/2016/October/581021c4_12/12.png)

# %%
"""
Check out the new network architecture and dataset!

Notice that the weights and biases are
generated randomly.

No need to change anything, but feel free to tweak
to test your network, play around with the epochs, batch size, etc!
"""

import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample
#from miniflow import *

# Load data
data = load_boston()
X_ = data['data']
y_ = data['target']

# Normalize data
X_ = (X_ - np.mean(X_, axis=0)) / np.std(X_, axis=0)

n_features = X_.shape[1]
n_hidden = 10
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# Neural network
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}

epochs = 1000
# Total number of examples
m = X_.shape[0]
batch_size = 11
steps_per_epoch = m // batch_size

graph = topological_sort(feed_dict)
trainables = [W1, b1, W2, b2]

print("Total number of examples = {}".format(m))

# Step 4
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        # Step 1
        # Randomly sample a batch of examples
        X_batch, y_batch = resample(X_, y_, n_samples=batch_size)

        # Reset value of X and y Inputs
        X.value = X_batch
        y.value = y_batch

        # Step 2
        forward_and_backward(graph)

        # Step 3
        sgd_update(trainables)

        loss += graph[-1].value

    print("Epoch: {}, Loss: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Total number of examples = 506
# Epoch: 1, Loss: 57.303
# Epoch: 2, Loss: 27.540
# Epoch: 3, Loss: 18.537
# Epoch: 4, Loss: 15.205
# Epoch: 5, Loss: 14.008
# Epoch: 6, Loss: 13.941
# Epoch: 7, Loss: 10.554
# Epoch: 8, Loss: 15.031
# Epoch: 9, Loss: 11.416
# Epoch: 10, Loss: 10.992
# Epoch: 11, Loss: 9.227
# Epoch: 12, Loss: 14.299
# Epoch: 13, Loss: 8.343
# Epoch: 14, Loss: 10.570
# Epoch: 15, Loss: 12.354
# Epoch: 16, Loss: 11.154
# Epoch: 17, Loss: 10.775
# Epoch: 18, Loss: 8.929
# Epoch: 19, Loss: 7.429
# Epoch: 20, Loss: 7.868
# Epoch: 21, Loss: 7.636
# Epoch: 22, Loss: 8.316
# Epoch: 23, Loss: 9.113
# Epoch: 24, Loss: 7.674
# Epoch: 25, Loss: 8.829
# Epoch: 26, Loss: 9.391
# Epoch: 27, Loss: 6.971
# Epoch: 28, Loss: 9.129
# Epoch: 29, Loss: 7.090
# Epoch: 30, Loss: 8.044
# Epoch: 31, Loss: 8.353
# Epoch: 32, Loss: 7.048
# Epoch: 33, Loss: 5.898
# Epoch: 34, Loss: 7.066
# Epoch: 35, Loss: 7.196
# Epoch: 36, Loss: 5.622
# Epoch: 37, Loss: 9.452
# Epoch: 38, Loss: 8.574
# Epoch: 39, Loss: 8.877
# Epoch: 40, Loss: 7.579
# Epoch: 41, Loss: 8.198
# Epoch: 42, Loss: 7.045
# Epoch: 43, Loss: 6.584
# Epoch: 44, Loss: 6.701
# Epoch: 45, Loss: 7.856
# Epoch: 46, Loss: 6.200
# Epoch: 47, Loss: 7.521
# Epoch: 48, Loss: 6.922
# Epoch: 49, Loss: 7.155
# Epoch: 50, Loss: 6.945
# Epoch: 51, Loss: 6.524
# Epoch: 52, Loss: 6.762
# Epoch: 53, Loss: 6.618
# Epoch: 54, Loss: 6.899
# Epoch: 55, Loss: 5.648
# Epoch: 56, Loss: 5.438
# Epoch: 57, Loss: 5.653
# Epoch: 58, Loss: 4.998
# Epoch: 59, Loss: 6.277
# Epoch: 60, Loss: 6.107
# Epoch: 61, Loss: 5.344
# Epoch: 62, Loss: 5.173
# Epoch: 63, Loss: 5.729
# Epoch: 64, Loss: 6.396
# Epoch: 65, Loss: 6.597
# Epoch: 66, Loss: 6.521
# Epoch: 67, Loss: 5.467
# Epoch: 68, Loss: 6.478
# Epoch: 69, Loss: 4.850
# Epoch: 70, Loss: 5.813
# Epoch: 71, Loss: 7.057
# Epoch: 72, Loss: 7.481
# Epoch: 73, Loss: 5.407
# Epoch: 74, Loss: 6.070
# Epoch: 75, Loss: 5.285
# Epoch: 76, Loss: 5.513
# Epoch: 77, Loss: 5.710
# Epoch: 78, Loss: 6.420
# Epoch: 79, Loss: 5.075
# Epoch: 80, Loss: 5.609
# Epoch: 81, Loss: 6.462
# Epoch: 82, Loss: 6.389
# Epoch: 83, Loss: 6.565
# Epoch: 84, Loss: 6.154
# Epoch: 85, Loss: 6.676
# Epoch: 86, Loss: 5.797
# Epoch: 87, Loss: 7.610
# Epoch: 88, Loss: 6.687
# Epoch: 89, Loss: 7.239
# Epoch: 90, Loss: 6.010
# Epoch: 91, Loss: 6.440
# Epoch: 92, Loss: 6.280
# Epoch: 93, Loss: 6.109
# Epoch: 94, Loss: 5.791
# Epoch: 95, Loss: 5.180
# Epoch: 96, Loss: 5.845
# Epoch: 97, Loss: 6.053
# Epoch: 98, Loss: 5.415
# Epoch: 99, Loss: 5.553
# Epoch: 100, Loss: 7.267
# Epoch: 101, Loss: 5.444
# Epoch: 102, Loss: 5.231
# Epoch: 103, Loss: 5.592
# Epoch: 104, Loss: 5.303
# Epoch: 105, Loss: 5.036
# Epoch: 106, Loss: 4.696
# Epoch: 107, Loss: 5.585
# Epoch: 108, Loss: 4.833
# Epoch: 109, Loss: 5.492
# Epoch: 110, Loss: 5.528
# Epoch: 111, Loss: 6.129
# Epoch: 112, Loss: 4.947
# Epoch: 113, Loss: 6.466
# Epoch: 114, Loss: 4.546
# Epoch: 115, Loss: 5.547
# Epoch: 116, Loss: 5.431
# Epoch: 117, Loss: 6.331
# Epoch: 118, Loss: 5.174
# Epoch: 119, Loss: 5.391
# Epoch: 120, Loss: 5.828
# Epoch: 121, Loss: 5.540
# Epoch: 122, Loss: 6.020
# Epoch: 123, Loss: 5.867
# Epoch: 124, Loss: 5.754
# Epoch: 125, Loss: 5.454
# Epoch: 126, Loss: 6.477
# Epoch: 127, Loss: 5.842
# Epoch: 128, Loss: 6.167
# Epoch: 129, Loss: 5.065
# Epoch: 130, Loss: 5.650
# Epoch: 131, Loss: 4.848
# Epoch: 132, Loss: 5.342
# Epoch: 133, Loss: 5.708
# Epoch: 134, Loss: 5.430
# Epoch: 135, Loss: 4.362
# Epoch: 136, Loss: 5.142
# Epoch: 137, Loss: 5.780
# Epoch: 138, Loss: 5.528
# Epoch: 139, Loss: 6.091
# Epoch: 140, Loss: 5.254
# Epoch: 141, Loss: 5.647
# Epoch: 142, Loss: 5.648
# Epoch: 143, Loss: 5.180
# Epoch: 144, Loss: 5.572
# Epoch: 145, Loss: 5.344
# Epoch: 146, Loss: 4.499
# Epoch: 147, Loss: 4.934
# Epoch: 148, Loss: 5.039
# Epoch: 149, Loss: 5.164
# Epoch: 150, Loss: 5.494
# Epoch: 151, Loss: 5.610
# Epoch: 152, Loss: 4.381
# Epoch: 153, Loss: 6.018
# Epoch: 154, Loss: 5.347
# Epoch: 155, Loss: 5.097
# Epoch: 156, Loss: 5.127
# Epoch: 157, Loss: 5.166
# Epoch: 158, Loss: 4.727
# Epoch: 159, Loss: 4.411
# Epoch: 160, Loss: 6.175
# Epoch: 161, Loss: 4.536
# Epoch: 162, Loss: 5.377
# Epoch: 163, Loss: 5.184
# Epoch: 164, Loss: 5.433
# Epoch: 165, Loss: 4.548
# Epoch: 166, Loss: 5.204
# Epoch: 167, Loss: 5.655
# Epoch: 168, Loss: 4.446
# Epoch: 169, Loss: 4.952
# Epoch: 170, Loss: 6.334
# Epoch: 171, Loss: 5.138
# Epoch: 172, Loss: 4.626
# Epoch: 173, Loss: 5.389
# Epoch: 174, Loss: 5.841
# Epoch: 175, Loss: 5.287
# Epoch: 176, Loss: 4.955
# Epoch: 177, Loss: 4.740
# Epoch: 178, Loss: 4.503
# Epoch: 179, Loss: 4.546
# Epoch: 180, Loss: 5.116
# Epoch: 181, Loss: 4.154
# Epoch: 182, Loss: 4.831
# Epoch: 183, Loss: 4.842
# Epoch: 184, Loss: 5.016
# Epoch: 185, Loss: 4.722
# Epoch: 186, Loss: 4.869
# Epoch: 187, Loss: 6.065
# Epoch: 188, Loss: 4.369
# Epoch: 189, Loss: 5.539
# Epoch: 190, Loss: 4.658
# Epoch: 191, Loss: 5.157
# Epoch: 192, Loss: 4.843
# Epoch: 193, Loss: 4.655
# Epoch: 194, Loss: 4.640
# Epoch: 195, Loss: 5.766
# Epoch: 196, Loss: 5.492
# Epoch: 197, Loss: 5.432
# Epoch: 198, Loss: 5.551
# Epoch: 199, Loss: 4.807
# Epoch: 200, Loss: 5.410
# Epoch: 201, Loss: 4.751
# Epoch: 202, Loss: 5.389
# Epoch: 203, Loss: 5.391
# Epoch: 204, Loss: 4.771
# Epoch: 205, Loss: 4.549
# Epoch: 206, Loss: 5.040
# Epoch: 207, Loss: 4.491
# Epoch: 208, Loss: 5.021
# Epoch: 209, Loss: 4.835
# Epoch: 210, Loss: 4.267
# Epoch: 211, Loss: 4.580
# Epoch: 212, Loss: 5.828
# Epoch: 213, Loss: 4.943
# Epoch: 214, Loss: 5.759
# Epoch: 215, Loss: 5.296
# Epoch: 216, Loss: 4.897
# Epoch: 217, Loss: 4.955
# Epoch: 218, Loss: 4.726
# Epoch: 219, Loss: 5.241
# Epoch: 220, Loss: 4.464
# Epoch: 221, Loss: 4.968
# Epoch: 222, Loss: 4.567
# Epoch: 223, Loss: 6.235
# Epoch: 224, Loss: 4.297
# Epoch: 225, Loss: 4.705
# Epoch: 226, Loss: 5.640
# Epoch: 227, Loss: 5.006
# Epoch: 228, Loss: 4.250
# Epoch: 229, Loss: 4.495
# Epoch: 230, Loss: 5.488
# Epoch: 231, Loss: 5.035
# Epoch: 232, Loss: 4.258
# Epoch: 233, Loss: 4.858
# Epoch: 234, Loss: 4.312
# Epoch: 235, Loss: 5.219
# Epoch: 236, Loss: 5.186
# Epoch: 237, Loss: 4.977
# Epoch: 238, Loss: 5.170
# Epoch: 239, Loss: 4.793
# Epoch: 240, Loss: 5.621
# Epoch: 241, Loss: 5.031
# Epoch: 242, Loss: 5.016
# Epoch: 243, Loss: 4.361
# Epoch: 244, Loss: 4.654
# Epoch: 245, Loss: 5.276
# Epoch: 246, Loss: 5.316
# Epoch: 247, Loss: 4.731
# Epoch: 248, Loss: 4.658
# Epoch: 249, Loss: 3.881
# Epoch: 250, Loss: 5.027
# Epoch: 251, Loss: 4.156
# Epoch: 252, Loss: 4.266
# Epoch: 253, Loss: 4.895
# Epoch: 254, Loss: 5.268
# Epoch: 255, Loss: 5.303
# Epoch: 256, Loss: 5.423
# Epoch: 257, Loss: 4.869
# Epoch: 258, Loss: 4.300
# Epoch: 259, Loss: 5.928
# Epoch: 260, Loss: 4.759
# Epoch: 261, Loss: 4.635
# Epoch: 262, Loss: 4.310
# Epoch: 263, Loss: 4.621
# Epoch: 264, Loss: 4.977
# Epoch: 265, Loss: 5.166
# Epoch: 266, Loss: 4.880
# Epoch: 267, Loss: 5.277
# Epoch: 268, Loss: 4.535
# Epoch: 269, Loss: 4.302
# Epoch: 270, Loss: 4.508
# Epoch: 271, Loss: 4.578
# Epoch: 272, Loss: 5.039
# Epoch: 273, Loss: 4.224
# Epoch: 274, Loss: 4.819
# Epoch: 275, Loss: 4.903
# Epoch: 276, Loss: 5.799
# Epoch: 277, Loss: 4.871
# Epoch: 278, Loss: 4.681
# Epoch: 279, Loss: 4.587
# Epoch: 280, Loss: 5.048
# Epoch: 281, Loss: 4.826
# Epoch: 282, Loss: 5.200
# Epoch: 283, Loss: 4.019
# Epoch: 284, Loss: 4.252
# Epoch: 285, Loss: 4.870
# Epoch: 286, Loss: 4.679
# Epoch: 287, Loss: 4.890
# Epoch: 288, Loss: 4.238
# Epoch: 289, Loss: 4.262
# Epoch: 290, Loss: 4.522
# Epoch: 291, Loss: 4.921
# Epoch: 292, Loss: 4.580
# Epoch: 293, Loss: 5.605
# Epoch: 294, Loss: 4.168
# Epoch: 295, Loss: 5.030
# Epoch: 296, Loss: 4.695
# Epoch: 297, Loss: 4.512
# Epoch: 298, Loss: 4.729
# Epoch: 299, Loss: 4.963
# Epoch: 300, Loss: 4.829
# Epoch: 301, Loss: 5.445
# Epoch: 302, Loss: 4.959
# Epoch: 303, Loss: 5.194
# Epoch: 304, Loss: 5.175
# Epoch: 305, Loss: 4.647
# Epoch: 306, Loss: 4.803
# Epoch: 307, Loss: 3.994
# Epoch: 308, Loss: 4.585
# Epoch: 309, Loss: 5.106
# Epoch: 310, Loss: 4.868
# Epoch: 311, Loss: 4.841
# Epoch: 312, Loss: 4.245
# Epoch: 313, Loss: 4.927
# Epoch: 314, Loss: 4.381
# Epoch: 315, Loss: 4.565
# Epoch: 316, Loss: 4.096
# Epoch: 317, Loss: 4.643
# Epoch: 318, Loss: 5.082
# Epoch: 319, Loss: 5.225
# Epoch: 320, Loss: 4.481
# Epoch: 321, Loss: 4.708
# Epoch: 322, Loss: 3.682
# Epoch: 323, Loss: 4.373
# Epoch: 324, Loss: 4.865
# Epoch: 325, Loss: 4.557
# Epoch: 326, Loss: 4.421
# Epoch: 327, Loss: 4.354
# Epoch: 328, Loss: 4.636
# Epoch: 329, Loss: 4.466
# Epoch: 330, Loss: 4.462
# Epoch: 331, Loss: 4.760
# Epoch: 332, Loss: 3.718
# Epoch: 333, Loss: 4.996
# Epoch: 334, Loss: 4.944
# Epoch: 335, Loss: 3.921
# Epoch: 336, Loss: 4.691
# Epoch: 337, Loss: 4.236
# Epoch: 338, Loss: 4.257
# Epoch: 339, Loss: 4.535
# Epoch: 340, Loss: 4.470
# Epoch: 341, Loss: 5.095
# Epoch: 342, Loss: 4.380
# Epoch: 343, Loss: 5.129
# Epoch: 344, Loss: 5.128
# Epoch: 345, Loss: 4.180
# Epoch: 346, Loss: 4.885
# Epoch: 347, Loss: 4.953
# Epoch: 348, Loss: 4.390
# Epoch: 349, Loss: 4.606
# Epoch: 350, Loss: 4.335
# Epoch: 351, Loss: 4.872
# Epoch: 352, Loss: 4.476
# Epoch: 353, Loss: 4.771
# Epoch: 354, Loss: 5.244
# Epoch: 355, Loss: 4.900
# Epoch: 356, Loss: 4.646
# Epoch: 357, Loss: 4.938
# Epoch: 358, Loss: 5.108
# Epoch: 359, Loss: 4.802
# Epoch: 360, Loss: 4.114
# Epoch: 361, Loss: 4.832
# Epoch: 362, Loss: 4.471
# Epoch: 363, Loss: 4.605
# Epoch: 364, Loss: 4.659
# Epoch: 365, Loss: 4.952
# Epoch: 366, Loss: 4.401
# Epoch: 367, Loss: 4.753
# Epoch: 368, Loss: 4.383
# Epoch: 369, Loss: 4.606
# Epoch: 370, Loss: 5.182
# Epoch: 371, Loss: 4.442
# Epoch: 372, Loss: 4.663
# Epoch: 373, Loss: 4.730
# Epoch: 374, Loss: 3.970
# Epoch: 375, Loss: 4.227
# Epoch: 376, Loss: 3.581
# Epoch: 377, Loss: 4.627
# Epoch: 378, Loss: 4.755
# Epoch: 379, Loss: 4.200
# Epoch: 380, Loss: 3.587
# Epoch: 381, Loss: 3.761
# Epoch: 382, Loss: 4.310
# Epoch: 383, Loss: 4.520
# Epoch: 384, Loss: 5.272
# Epoch: 385, Loss: 4.889
# Epoch: 386, Loss: 4.394
# Epoch: 387, Loss: 4.099
# Epoch: 388, Loss: 4.764
# Epoch: 389, Loss: 3.550
# Epoch: 390, Loss: 4.282
# Epoch: 391, Loss: 4.473
# Epoch: 392, Loss: 4.123
# Epoch: 393, Loss: 4.549
# Epoch: 394, Loss: 3.992
# Epoch: 395, Loss: 4.784
# Epoch: 396, Loss: 4.659
# Epoch: 397, Loss: 4.308
# Epoch: 398, Loss: 4.547
# Epoch: 399, Loss: 4.560
# Epoch: 400, Loss: 4.748
# Epoch: 401, Loss: 4.204
# Epoch: 402, Loss: 4.751
# Epoch: 403, Loss: 4.580
# Epoch: 404, Loss: 4.689
# Epoch: 405, Loss: 4.837
# Epoch: 406, Loss: 4.104
# Epoch: 407, Loss: 4.385
# Epoch: 408, Loss: 5.154
# Epoch: 409, Loss: 4.401
# Epoch: 410, Loss: 4.993
# Epoch: 411, Loss: 3.737
# Epoch: 412, Loss: 3.654
# Epoch: 413, Loss: 4.205
# Epoch: 414, Loss: 4.761
# Epoch: 415, Loss: 3.900
# Epoch: 416, Loss: 4.123
# Epoch: 417, Loss: 4.280
# Epoch: 418, Loss: 4.234
# Epoch: 419, Loss: 3.885
# Epoch: 420, Loss: 4.211
# Epoch: 421, Loss: 4.470
# Epoch: 422, Loss: 5.183
# Epoch: 423, Loss: 4.533
# Epoch: 424, Loss: 5.061
# Epoch: 425, Loss: 4.519
# Epoch: 426, Loss: 4.542
# Epoch: 427, Loss: 4.796
# Epoch: 428, Loss: 4.284
# Epoch: 429, Loss: 4.529
# Epoch: 430, Loss: 4.625
# Epoch: 431, Loss: 4.775
# Epoch: 432, Loss: 4.363
# Epoch: 433, Loss: 4.560
# Epoch: 434, Loss: 4.272
# Epoch: 435, Loss: 3.900
# Epoch: 436, Loss: 4.179
# Epoch: 437, Loss: 4.775
# Epoch: 438, Loss: 5.320
# Epoch: 439, Loss: 4.702
# Epoch: 440, Loss: 4.931
# Epoch: 441, Loss: 3.662
# Epoch: 442, Loss: 4.058
# Epoch: 443, Loss: 4.259
# Epoch: 444, Loss: 4.322
# Epoch: 445, Loss: 4.572
# Epoch: 446, Loss: 4.559
# Epoch: 447, Loss: 4.232
# Epoch: 448, Loss: 5.282
# Epoch: 449, Loss: 3.784
# Epoch: 450, Loss: 4.970
# Epoch: 451, Loss: 4.341
# Epoch: 452, Loss: 4.382
# Epoch: 453, Loss: 3.928
# Epoch: 454, Loss: 4.836
# Epoch: 455, Loss: 4.527
# Epoch: 456, Loss: 4.553
# Epoch: 457, Loss: 4.594
# Epoch: 458, Loss: 3.864
# Epoch: 459, Loss: 3.718
# Epoch: 460, Loss: 4.954
# Epoch: 461, Loss: 4.505
# Epoch: 462, Loss: 4.322
# Epoch: 463, Loss: 4.712
# Epoch: 464, Loss: 4.313
# Epoch: 465, Loss: 4.879
# Epoch: 466, Loss: 4.308
# Epoch: 467, Loss: 3.939
# Epoch: 468, Loss: 4.494
# Epoch: 469, Loss: 4.945
# Epoch: 470, Loss: 4.000
# Epoch: 471, Loss: 4.100
# Epoch: 472, Loss: 4.153
# Epoch: 473, Loss: 4.663
# Epoch: 474, Loss: 3.734
# Epoch: 475, Loss: 4.157
# Epoch: 476, Loss: 4.418
# Epoch: 477, Loss: 4.285
# Epoch: 478, Loss: 5.014
# Epoch: 479, Loss: 3.838
# Epoch: 480, Loss: 4.731
# Epoch: 481, Loss: 3.960
# Epoch: 482, Loss: 4.878
# Epoch: 483, Loss: 4.806
# Epoch: 484, Loss: 4.467
# Epoch: 485, Loss: 4.963
# Epoch: 486, Loss: 5.223
# Epoch: 487, Loss: 4.841
# Epoch: 488, Loss: 4.600
# Epoch: 489, Loss: 4.053
# Epoch: 490, Loss: 4.553
# Epoch: 491, Loss: 4.064
# Epoch: 492, Loss: 4.315
# Epoch: 493, Loss: 4.600
# Epoch: 494, Loss: 3.587
# Epoch: 495, Loss: 4.424
# Epoch: 496, Loss: 4.584
# Epoch: 497, Loss: 4.066
# Epoch: 498, Loss: 4.174
# Epoch: 499, Loss: 3.910
# Epoch: 500, Loss: 4.083
# Epoch: 501, Loss: 4.108
# Epoch: 502, Loss: 5.787
# Epoch: 503, Loss: 4.383
# Epoch: 504, Loss: 4.139
# Epoch: 505, Loss: 4.362
# Epoch: 506, Loss: 4.370
# Epoch: 507, Loss: 4.117
# Epoch: 508, Loss: 5.335
# Epoch: 509, Loss: 4.703
# Epoch: 510, Loss: 4.757
# Epoch: 511, Loss: 4.990
# Epoch: 512, Loss: 4.055
# Epoch: 513, Loss: 4.231
# Epoch: 514, Loss: 4.172
# Epoch: 515, Loss: 4.855
# Epoch: 516, Loss: 4.115
# Epoch: 517, Loss: 4.420
# Epoch: 518, Loss: 4.275
# Epoch: 519, Loss: 4.200
# Epoch: 520, Loss: 4.092
# Epoch: 521, Loss: 4.310
# Epoch: 522, Loss: 4.425
# Epoch: 523, Loss: 4.231
# Epoch: 524, Loss: 3.857
# Epoch: 525, Loss: 4.672
# Epoch: 526, Loss: 4.751
# Epoch: 527, Loss: 4.384
# Epoch: 528, Loss: 3.695
# Epoch: 529, Loss: 4.372
# Epoch: 530, Loss: 3.743
# Epoch: 531, Loss: 4.051
# Epoch: 532, Loss: 4.825
# Epoch: 533, Loss: 3.877
# Epoch: 534, Loss: 4.527
# Epoch: 535, Loss: 4.566
# Epoch: 536, Loss: 3.825
# Epoch: 537, Loss: 5.029
# Epoch: 538, Loss: 4.223
# Epoch: 539, Loss: 4.267
# Epoch: 540, Loss: 4.537
# Epoch: 541, Loss: 3.857
# Epoch: 542, Loss: 4.413
# Epoch: 543, Loss: 4.760
# Epoch: 544, Loss: 4.182
# Epoch: 545, Loss: 4.606
# Epoch: 546, Loss: 4.502
# Epoch: 547, Loss: 4.393
# Epoch: 548, Loss: 4.499
# Epoch: 549, Loss: 3.930
# Epoch: 550, Loss: 4.316
# Epoch: 551, Loss: 4.584
# Epoch: 552, Loss: 4.346
# Epoch: 553, Loss: 4.374
# Epoch: 554, Loss: 4.651
# Epoch: 555, Loss: 5.120
# Epoch: 556, Loss: 4.665
# Epoch: 557, Loss: 4.419
# Epoch: 558, Loss: 5.353
# Epoch: 559, Loss: 4.054
# Epoch: 560, Loss: 4.811
# Epoch: 561, Loss: 4.864
# Epoch: 562, Loss: 4.415
# Epoch: 563, Loss: 4.598
# Epoch: 564, Loss: 4.825
# Epoch: 565, Loss: 4.288
# Epoch: 566, Loss: 4.191
# Epoch: 567, Loss: 4.102
# Epoch: 568, Loss: 4.532
# Epoch: 569, Loss: 5.002
# Epoch: 570, Loss: 3.624
# Epoch: 571, Loss: 4.305
# Epoch: 572, Loss: 5.068
# Epoch: 573, Loss: 4.065
# Epoch: 574, Loss: 4.984
# Epoch: 575, Loss: 4.317
# Epoch: 576, Loss: 4.647
# Epoch: 577, Loss: 4.456
# Epoch: 578, Loss: 4.277
# Epoch: 579, Loss: 4.569
# Epoch: 580, Loss: 4.527
# Epoch: 581, Loss: 3.864
# Epoch: 582, Loss: 4.584
# Epoch: 583, Loss: 5.128
# Epoch: 584, Loss: 4.493
# Epoch: 585, Loss: 4.325
# Epoch: 586, Loss: 4.316
# Epoch: 587, Loss: 4.428
# Epoch: 588, Loss: 3.991
# Epoch: 589, Loss: 4.382
# Epoch: 590, Loss: 3.812
# Epoch: 591, Loss: 3.978
# Epoch: 592, Loss: 4.577
# Epoch: 593, Loss: 4.289
# Epoch: 594, Loss: 4.029
# Epoch: 595, Loss: 3.919
# Epoch: 596, Loss: 4.391
# Epoch: 597, Loss: 4.460
# Epoch: 598, Loss: 4.598
# Epoch: 599, Loss: 4.061
# Epoch: 600, Loss: 3.769
# Epoch: 601, Loss: 4.568
# Epoch: 602, Loss: 3.896
# Epoch: 603, Loss: 3.955
# Epoch: 604, Loss: 4.403
# Epoch: 605, Loss: 4.319
# Epoch: 606, Loss: 3.972
# Epoch: 607, Loss: 3.679
# Epoch: 608, Loss: 4.286
# Epoch: 609, Loss: 4.031
# Epoch: 610, Loss: 4.468
# Epoch: 611, Loss: 3.828
# Epoch: 612, Loss: 4.448
# Epoch: 613, Loss: 4.272
# Epoch: 614, Loss: 3.921
# Epoch: 615, Loss: 4.576
# Epoch: 616, Loss: 3.742
# Epoch: 617, Loss: 4.052
# Epoch: 618, Loss: 4.198
# Epoch: 619, Loss: 4.070
# Epoch: 620, Loss: 4.537
# Epoch: 621, Loss: 4.484
# Epoch: 622, Loss: 4.423
# Epoch: 623, Loss: 4.653
# Epoch: 624, Loss: 3.897
# Epoch: 625, Loss: 4.550
# Epoch: 626, Loss: 4.072
# Epoch: 627, Loss: 3.775
# Epoch: 628, Loss: 4.039
# Epoch: 629, Loss: 4.235
# Epoch: 630, Loss: 4.329
# Epoch: 631, Loss: 3.915
# Epoch: 632, Loss: 4.469
# Epoch: 633, Loss: 3.466
# Epoch: 634, Loss: 4.054
# Epoch: 635, Loss: 3.782
# Epoch: 636, Loss: 3.938
# Epoch: 637, Loss: 3.894
# Epoch: 638, Loss: 4.261
# Epoch: 639, Loss: 4.531
# Epoch: 640, Loss: 5.086
# Epoch: 641, Loss: 4.450
# Epoch: 642, Loss: 3.889
# Epoch: 643, Loss: 3.846
# Epoch: 644, Loss: 4.334
# Epoch: 645, Loss: 4.067
# Epoch: 646, Loss: 4.592
# Epoch: 647, Loss: 4.052
# Epoch: 648, Loss: 4.773
# Epoch: 649, Loss: 4.377
# Epoch: 650, Loss: 3.991
# Epoch: 651, Loss: 4.304
# Epoch: 652, Loss: 4.461
# Epoch: 653, Loss: 4.096
# Epoch: 654, Loss: 4.750
# Epoch: 655, Loss: 4.332
# Epoch: 656, Loss: 3.774
# Epoch: 657, Loss: 4.040
# Epoch: 658, Loss: 4.138
# Epoch: 659, Loss: 3.765
# Epoch: 660, Loss: 4.474
# Epoch: 661, Loss: 4.287
# Epoch: 662, Loss: 4.058
# Epoch: 663, Loss: 5.167
# Epoch: 664, Loss: 4.290
# Epoch: 665, Loss: 4.818
# Epoch: 666, Loss: 3.776
# Epoch: 667, Loss: 4.398
# Epoch: 668, Loss: 4.288
# Epoch: 669, Loss: 3.970
# Epoch: 670, Loss: 4.197
# Epoch: 671, Loss: 4.005
# Epoch: 672, Loss: 4.137
# Epoch: 673, Loss: 4.531
# Epoch: 674, Loss: 3.774
# Epoch: 675, Loss: 3.766
# Epoch: 676, Loss: 4.137
# Epoch: 677, Loss: 3.694
# Epoch: 678, Loss: 4.213
# Epoch: 679, Loss: 4.367
# Epoch: 680, Loss: 4.239
# Epoch: 681, Loss: 4.232
# Epoch: 682, Loss: 4.772
# Epoch: 683, Loss: 4.340
# Epoch: 684, Loss: 4.240
# Epoch: 685, Loss: 4.761
# Epoch: 686, Loss: 4.074
# Epoch: 687, Loss: 3.935
# Epoch: 688, Loss: 4.188
# Epoch: 689, Loss: 4.622
# Epoch: 690, Loss: 3.873
# Epoch: 691, Loss: 4.031
# Epoch: 692, Loss: 4.102
# Epoch: 693, Loss: 3.873
# Epoch: 694, Loss: 4.162
# Epoch: 695, Loss: 4.977
# Epoch: 696, Loss: 3.821
# Epoch: 697, Loss: 4.309
# Epoch: 698, Loss: 4.322
# Epoch: 699, Loss: 4.889
# Epoch: 700, Loss: 3.534
# Epoch: 701, Loss: 3.904
# Epoch: 702, Loss: 4.330
# Epoch: 703, Loss: 4.307
# Epoch: 704, Loss: 4.923
# Epoch: 705, Loss: 4.259
# Epoch: 706, Loss: 4.007
# Epoch: 707, Loss: 4.255
# Epoch: 708, Loss: 4.146
# Epoch: 709, Loss: 3.919
# Epoch: 710, Loss: 4.412
# Epoch: 711, Loss: 4.248
# Epoch: 712, Loss: 4.378
# Epoch: 713, Loss: 4.374
# Epoch: 714, Loss: 4.088
# Epoch: 715, Loss: 3.726
# Epoch: 716, Loss: 4.259
# Epoch: 717, Loss: 4.085
# Epoch: 718, Loss: 3.325
# Epoch: 719, Loss: 3.764
# Epoch: 720, Loss: 4.261
# Epoch: 721, Loss: 4.983
# Epoch: 722, Loss: 3.988
# Epoch: 723, Loss: 4.077
# Epoch: 724, Loss: 4.396
# Epoch: 725, Loss: 4.041
# Epoch: 726, Loss: 4.001
# Epoch: 727, Loss: 4.197
# Epoch: 728, Loss: 4.432
# Epoch: 729, Loss: 4.327
# Epoch: 730, Loss: 4.426
# Epoch: 731, Loss: 3.519
# Epoch: 732, Loss: 4.789
# Epoch: 733, Loss: 4.087
# Epoch: 734, Loss: 3.696
# Epoch: 735, Loss: 4.300
# Epoch: 736, Loss: 4.248
# Epoch: 737, Loss: 4.390
# Epoch: 738, Loss: 3.956
# Epoch: 739, Loss: 4.202
# Epoch: 740, Loss: 4.300
# Epoch: 741, Loss: 4.224
# Epoch: 742, Loss: 4.345
# Epoch: 743, Loss: 3.928
# Epoch: 744, Loss: 3.938
# Epoch: 745, Loss: 5.114
# Epoch: 746, Loss: 4.406
# Epoch: 747, Loss: 4.075
# Epoch: 748, Loss: 4.001
# Epoch: 749, Loss: 3.798
# Epoch: 750, Loss: 4.617
# Epoch: 751, Loss: 4.133
# Epoch: 752, Loss: 3.605
# Epoch: 753, Loss: 4.646
# Epoch: 754, Loss: 4.585
# Epoch: 755, Loss: 3.743
# Epoch: 756, Loss: 3.987
# Epoch: 757, Loss: 3.860
# Epoch: 758, Loss: 4.642
# Epoch: 759, Loss: 4.464
# Epoch: 760, Loss: 3.860
# Epoch: 761, Loss: 3.918
# Epoch: 762, Loss: 4.228
# Epoch: 763, Loss: 3.893
# Epoch: 764, Loss: 4.138
# Epoch: 765, Loss: 3.419
# Epoch: 766, Loss: 4.913
# Epoch: 767, Loss: 5.052
# Epoch: 768, Loss: 4.935
# Epoch: 769, Loss: 3.574
# Epoch: 770, Loss: 4.049
# Epoch: 771, Loss: 4.025
# Epoch: 772, Loss: 4.267
# Epoch: 773, Loss: 4.418
# Epoch: 774, Loss: 4.426
# Epoch: 775, Loss: 4.107
# Epoch: 776, Loss: 4.949
# Epoch: 777, Loss: 4.281
# Epoch: 778, Loss: 4.520
# Epoch: 779, Loss: 4.694
# Epoch: 780, Loss: 4.277
# Epoch: 781, Loss: 4.294
# Epoch: 782, Loss: 4.006
# Epoch: 783, Loss: 3.662
# Epoch: 784, Loss: 3.933
# Epoch: 785, Loss: 4.339
# Epoch: 786, Loss: 4.039
# Epoch: 787, Loss: 3.730
# Epoch: 788, Loss: 3.795
# Epoch: 789, Loss: 4.099
# Epoch: 790, Loss: 3.739
# Epoch: 791, Loss: 4.260
# Epoch: 792, Loss: 4.360
# Epoch: 793, Loss: 4.074
# Epoch: 794, Loss: 4.311
# Epoch: 795, Loss: 4.552
# Epoch: 796, Loss: 4.888
# Epoch: 797, Loss: 3.519
# Epoch: 798, Loss: 4.090
# Epoch: 799, Loss: 3.690
# Epoch: 800, Loss: 3.684
# Epoch: 801, Loss: 3.471
# Epoch: 802, Loss: 4.787
# Epoch: 803, Loss: 4.294
# Epoch: 804, Loss: 3.838
# Epoch: 805, Loss: 3.835
# Epoch: 806, Loss: 3.769
# Epoch: 807, Loss: 4.215
# Epoch: 808, Loss: 3.808
# Epoch: 809, Loss: 3.459
# Epoch: 810, Loss: 4.458
# Epoch: 811, Loss: 4.496
# Epoch: 812, Loss: 4.380
# Epoch: 813, Loss: 4.446
# Epoch: 814, Loss: 4.356
# Epoch: 815, Loss: 4.653
# Epoch: 816, Loss: 5.123
# Epoch: 817, Loss: 4.312
# Epoch: 818, Loss: 4.497
# Epoch: 819, Loss: 3.685
# Epoch: 820, Loss: 3.391
# Epoch: 821, Loss: 4.534
# Epoch: 822, Loss: 4.027
# Epoch: 823, Loss: 4.052
# Epoch: 824, Loss: 3.740
# Epoch: 825, Loss: 4.015
# Epoch: 826, Loss: 5.106
# Epoch: 827, Loss: 3.997
# Epoch: 828, Loss: 3.980
# Epoch: 829, Loss: 4.190
# Epoch: 830, Loss: 4.210
# Epoch: 831, Loss: 3.358
# Epoch: 832, Loss: 3.805
# Epoch: 833, Loss: 3.810
# Epoch: 834, Loss: 4.473
# Epoch: 835, Loss: 3.999
# Epoch: 836, Loss: 3.697
# Epoch: 837, Loss: 3.617
# Epoch: 838, Loss: 3.571
# Epoch: 839, Loss: 3.523
# Epoch: 840, Loss: 3.758
# Epoch: 841, Loss: 3.827
# Epoch: 842, Loss: 4.404
# Epoch: 843, Loss: 4.331
# Epoch: 844, Loss: 4.129
# Epoch: 845, Loss: 4.258
# Epoch: 846, Loss: 4.363
# Epoch: 847, Loss: 3.633
# Epoch: 848, Loss: 3.732
# Epoch: 849, Loss: 4.042
# Epoch: 850, Loss: 4.761
# Epoch: 851, Loss: 4.782
# Epoch: 852, Loss: 4.046
# Epoch: 853, Loss: 4.912
# Epoch: 854, Loss: 4.281
# Epoch: 855, Loss: 3.852
# Epoch: 856, Loss: 4.352
# Epoch: 857, Loss: 4.203
# Epoch: 858, Loss: 4.002
# Epoch: 859, Loss: 4.303
# Epoch: 860, Loss: 4.019
# Epoch: 861, Loss: 4.060
# Epoch: 862, Loss: 3.997
# Epoch: 863, Loss: 3.818
# Epoch: 864, Loss: 4.329
# Epoch: 865, Loss: 3.767
# Epoch: 866, Loss: 3.721
# Epoch: 867, Loss: 4.053
# Epoch: 868, Loss: 3.872
# Epoch: 869, Loss: 4.286
# Epoch: 870, Loss: 3.883
# Epoch: 871, Loss: 4.065
# Epoch: 872, Loss: 3.931
# Epoch: 873, Loss: 4.042
# Epoch: 874, Loss: 4.631
# Epoch: 875, Loss: 4.696
# Epoch: 876, Loss: 4.949
# Epoch: 877, Loss: 3.706
# Epoch: 878, Loss: 4.694
# Epoch: 879, Loss: 4.325
# Epoch: 880, Loss: 3.784
# Epoch: 881, Loss: 4.451
# Epoch: 882, Loss: 4.342
# Epoch: 883, Loss: 4.146
# Epoch: 884, Loss: 3.980
# Epoch: 885, Loss: 4.113
# Epoch: 886, Loss: 3.859
# Epoch: 887, Loss: 4.082
# Epoch: 888, Loss: 4.838
# Epoch: 889, Loss: 3.732
# Epoch: 890, Loss: 4.211
# Epoch: 891, Loss: 4.393
# Epoch: 892, Loss: 4.228
# Epoch: 893, Loss: 4.260
# Epoch: 894, Loss: 4.505
# Epoch: 895, Loss: 4.444
# Epoch: 896, Loss: 3.820
# Epoch: 897, Loss: 3.600
# Epoch: 898, Loss: 4.532
# Epoch: 899, Loss: 4.523
# Epoch: 900, Loss: 4.004
# Epoch: 901, Loss: 4.578
# Epoch: 902, Loss: 3.724
# Epoch: 903, Loss: 3.948
# Epoch: 904, Loss: 4.265
# Epoch: 905, Loss: 4.237
# Epoch: 906, Loss: 4.562
# Epoch: 907, Loss: 4.174
# Epoch: 908, Loss: 3.831
# Epoch: 909, Loss: 3.545
# Epoch: 910, Loss: 4.322
# Epoch: 911, Loss: 4.158
# Epoch: 912, Loss: 3.905
# Epoch: 913, Loss: 3.691
# Epoch: 914, Loss: 3.908
# Epoch: 915, Loss: 3.934
# Epoch: 916, Loss: 4.286
# Epoch: 917, Loss: 3.969
# Epoch: 918, Loss: 4.198
# Epoch: 919, Loss: 4.070
# Epoch: 920, Loss: 3.448
# Epoch: 921, Loss: 4.137
# Epoch: 922, Loss: 3.705
# Epoch: 923, Loss: 4.515
# Epoch: 924, Loss: 4.636
# Epoch: 925, Loss: 4.108
# Epoch: 926, Loss: 3.765
# Epoch: 927, Loss: 4.514
# Epoch: 928, Loss: 3.949
# Epoch: 929, Loss: 3.852
# Epoch: 930, Loss: 4.172
# Epoch: 931, Loss: 3.826
# Epoch: 932, Loss: 3.710
# Epoch: 933, Loss: 4.356
# Epoch: 934, Loss: 4.126
# Epoch: 935, Loss: 3.692
# Epoch: 936, Loss: 3.634
# Epoch: 937, Loss: 4.264
# Epoch: 938, Loss: 3.630
# Epoch: 939, Loss: 3.105
# Epoch: 940, Loss: 4.368
# Epoch: 941, Loss: 4.123
# Epoch: 942, Loss: 4.073
# Epoch: 943, Loss: 4.121
# Epoch: 944, Loss: 4.645
# Epoch: 945, Loss: 4.246
# Epoch: 946, Loss: 4.678
# Epoch: 947, Loss: 4.451
# Epoch: 948, Loss: 4.147
# Epoch: 949, Loss: 3.768
# Epoch: 950, Loss: 4.713
# Epoch: 951, Loss: 4.134
# Epoch: 952, Loss: 3.777
# Epoch: 953, Loss: 4.210
# Epoch: 954, Loss: 4.417
# Epoch: 955, Loss: 3.726
# Epoch: 956, Loss: 3.709
# Epoch: 957, Loss: 4.218
# Epoch: 958, Loss: 4.747
# Epoch: 959, Loss: 3.942
# Epoch: 960, Loss: 3.938
# Epoch: 961, Loss: 4.274
# Epoch: 962, Loss: 3.931
# Epoch: 963, Loss: 3.866
# Epoch: 964, Loss: 4.309
# Epoch: 965, Loss: 3.978
# Epoch: 966, Loss: 4.175
# Epoch: 967, Loss: 4.336
# Epoch: 968, Loss: 4.142
# Epoch: 969, Loss: 4.494
# Epoch: 970, Loss: 3.629
# Epoch: 971, Loss: 3.634
# Epoch: 972, Loss: 4.200
# Epoch: 973, Loss: 3.790
# Epoch: 974, Loss: 4.413
# Epoch: 975, Loss: 3.963
# Epoch: 976, Loss: 4.609
# Epoch: 977, Loss: 3.986
# Epoch: 978, Loss: 4.224
# Epoch: 979, Loss: 4.783
# Epoch: 980, Loss: 4.937
# Epoch: 981, Loss: 3.633
# Epoch: 982, Loss: 4.646
# Epoch: 983, Loss: 4.299
# Epoch: 984, Loss: 4.400
# Epoch: 985, Loss: 3.972
# Epoch: 986, Loss: 4.535
# Epoch: 987, Loss: 4.408
# Epoch: 988, Loss: 3.778
# Epoch: 989, Loss: 4.146
# Epoch: 990, Loss: 3.710
# Epoch: 991, Loss: 3.522
# Epoch: 992, Loss: 4.412
# Epoch: 993, Loss: 3.746
# Epoch: 994, Loss: 4.120
# Epoch: 995, Loss: 4.512
# Epoch: 996, Loss: 3.438
# Epoch: 997, Loss: 4.038
# Epoch: 998, Loss: 4.053
# Epoch: 999, Loss: 4.420
# Epoch: 1000, Loss: 4.244
